# %%
import sys
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib
from PIL import Image
import cv2
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
df = pd.read_csv("Task4.csv")
df
# Out:
#      Unnamed: 0  Epochs  Batch Size  Learning Rate  Dropout Rate  FC1 Nodes  \
# 0             0       3          32          0.001           0.2         10
# 1             1       6          32          0.001           0.2         10
# 2             2       9          32          0.001           0.2         10
# 3             3       3          32          0.001           0.2         30
# 4             4       6          32          0.001           0.2         30
# ..          ...     ...         ...            ...           ...        ...
# 103         103       6         256          0.010           1.0         30
# 104         104       9         256          0.010           1.0         30
# 105         105       3         256          0.010           1.0         50
# 106         106       6         256          0.010           1.0         50
# 107         107       9         256          0.010           1.0         50
#
#       Accuracy                                       train_losses  \
# 0    65.699997  [2.3779895305633545, 2.298424482345581, 2.2997...
# 1    71.620003  [2.3779895305633545, 2.298424482345581, 2.2997...
# 2    74.900002  [2.3779895305633545, 2.298424482345581, 2.2997...
# 3    72.269997  [2.3386623859405518, 2.3343656063079834, 2.347...
# 4    75.629997  [2.3386623859405518, 2.3343656063079834, 2.347...
# ..         ...                                                ...
# 103  10.230000  [2.3041088581085205, 2.3246684074401855, 2.309...
# 104  10.210000  [2.3041088581085205, 2.3246684074401855, 2.309...
# 105  11.460000  [2.303673267364502, 2.3031933307647705, 2.3070...
# 106  11.860000  [2.303673267364502, 2.3031933307647705, 2.3070...
# 107  12.110000  [2.303673267364502, 2.3031933307647705, 2.3070...
#
#                                          train_counter  \
# 0    [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 1    [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 2    [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 3    [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 4    [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# ..                                                 ...
# 103  [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 104  [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 105  [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 106  [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 107  [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
#
#                                            test_losses  \
# 0    [2.3217968017578126, 1.7890741333007814, 1.284...
# 1    [2.3217968017578126, 1.7890741333007814, 1.284...
# 2    [2.3217968017578126, 1.7890741333007814, 1.284...
# 3    [2.312999560546875, 1.1253486328125, 0.8473098...
# 4    [2.312999560546875, 1.1253486328125, 0.8473098...
# ..                                                 ...
# 103  [2.312999560546875, 2.30888603515625, 2.307604...
# 104  [2.312999560546875, 2.30888603515625, 2.307604...
# 105  [2.3021302978515625, 2.3005751708984374, 2.300...
# 106  [2.3021302978515625, 2.3005751708984374, 2.300...
# 107  [2.3021302978515625, 2.3005751708984374, 2.300...
#
#                                           test_counter
# 0    [0, 60000, 120000, 180000, 240000, 300000, 360...
# 1    [0, 60000, 120000, 180000, 240000, 300000, 360...
# 2    [0, 60000, 120000, 180000, 240000, 300000, 360...
# 3    [0, 60000, 120000, 180000, 240000, 300000, 360...
# 4    [0, 60000, 120000, 180000, 240000, 300000, 360...
# ..                                                 ...
# 103  [0, 60000, 120000, 180000, 240000, 300000, 360...
# 104  [0, 60000, 120000, 180000, 240000, 300000, 360...
# 105  [0, 60000, 120000, 180000, 240000, 300000, 360...
# 106  [0, 60000, 120000, 180000, 240000, 300000, 360...
# 107  [0, 60000, 120000, 180000, 240000, 300000, 360...
#
# [108 rows x 11 columns]

# %%
def meanGB(df):
    l = ["Epochs", "Batch Size", "Learning Rate", "Dropout Rate", "FC1 Nodes"]
    for i in l:
        print(df.groupby(by = i)["Accuracy"].mean(), "\n")
        print(df.groupby(by = i)["Accuracy"].median(), "\n")

# %%
meanGB(df)
# Out:
# Epochs
# 3    44.325278
# 6    50.091944
# 9    52.657500
# Name: Accuracy, dtype: float64
#
# Epochs
# 3    51.139999
# 6    66.599998
# 9    70.260002
# Name: Accuracy, dtype: float64
#
# Batch Size
# 32     55.107037
# 256    42.942777
# Name: Accuracy, dtype: float64
#
# Batch Size
# 32     73.835003
# 256    43.809999
# Name: Accuracy, dtype: float64
#
# Learning Rate
# 0.001    42.880926
# 0.010    55.168888
# Name: Accuracy, dtype: float64
#
# Learning Rate
# 0.001    43.809999
# 0.010    74.160000
# Name: Accuracy, dtype: float64
#
# Dropout Rate
# 0.2    69.049721
# 0.5    67.380556
# 1.0    10.644445
# Name: Accuracy, dtype: float64
#
# Dropout Rate
# 0.2    74.730000
# 0.5    73.835003
# 1.0    10.445000
# Name: Accuracy, dtype: float64
#
# FC1 Nodes
# 10    43.488611
# 30    50.777499
# 50    52.808611
# Name: Accuracy, dtype: float64
#
# FC1 Nodes
# 10    52.350000
# 30    68.630001
# 50    69.200001
# Name: Accuracy, dtype: float64

# %%
df.sort_values('Accuracy', ascending=False)
# Out:
#      Unnamed: 0  Epochs  Batch Size  Learning Rate  Dropout Rate  FC1 Nodes  \
# 35           35       9          32          0.010           0.2         50
# 32           32       9          32          0.010           0.2         30
# 34           34       6          32          0.010           0.2         50
# 44           44       9          32          0.010           0.5         50
# 31           31       6          32          0.010           0.2         30
# ..          ...     ...         ...            ...           ...        ...
# 101         101       9         256          0.010           1.0         10
# 100         100       6         256          0.010           1.0         10
# 53           53       9          32          0.010           1.0         50
# 20           20       9          32          0.001           1.0         10
# 46           46       6          32          0.010           1.0         10
#
#       Accuracy                                       train_losses  \
# 35   87.860001  [2.3274571895599365, 2.2662808895111084, 2.290...
# 32   86.769997  [2.3386623859405518, 2.3225855827331543, 2.328...
# 34   86.650002  [2.3274571895599365, 2.2662808895111084, 2.290...
# 44   86.510002  [2.3311424255371094, 2.287510395050049, 2.2955...
# 31   86.019997  [2.3386623859405518, 2.3225855827331543, 2.328...
# ..         ...                                                ...
# 101   8.350000  [2.31144642829895, 2.3155324459075928, 2.31856...
# 100   8.100000  [2.31144642829895, 2.3155324459075928, 2.31856...
# 53    8.050000  [2.3198084831237793, 2.275465965270996, 2.3148...
# 20    7.720000  [2.3537378311157227, 2.2922515869140625, 2.289...
# 46    4.050000  [2.3537378311157227, 2.292309284210205, 2.2915...
#
#                                          train_counter  \
# 35   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 32   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 34   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 44   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 31   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# ..                                                 ...
# 101  [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 100  [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 53   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 20   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 46   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
#
#                                            test_losses  \
# 35   [2.3021302978515625, 0.5811319152832031, 0.487...
# 32   [2.312999560546875, 0.6073333923339844, 0.5137...
# 34   [2.3021302978515625, 0.5811319152832031, 0.487...
# 44   [2.3021302978515625, 0.6238296569824219, 0.537...
# 31   [2.312999560546875, 0.6073333923339844, 0.5137...
# ..                                                 ...
# 101  [2.3217968017578126, 2.3130224609375, 2.309640...
# 100  [2.3217968017578126, 2.3130224609375, 2.309640...
# 53   [2.3021302978515625, 2.3000744384765626, 2.299...
# 20   [2.3217968017578126, 2.3142005126953125, 2.310...
# 46   [2.3217968017578126, 2.3074344482421876, 2.307...
#
#                                           test_counter
# 35   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 32   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 34   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 44   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 31   [0, 60000, 120000, 180000, 240000, 300000, 360...
# ..                                                 ...
# 101  [0, 60000, 120000, 180000, 240000, 300000, 360...
# 100  [0, 60000, 120000, 180000, 240000, 300000, 360...
# 53   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 20   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 46   [0, 60000, 120000, 180000, 240000, 300000, 360...
#
# [108 rows x 11 columns]

# %%
df.sort_values('Accuracy')
# Out:
#      Unnamed: 0  Epochs  Batch Size  Learning Rate  Dropout Rate  FC1 Nodes  \
# 46           46       6          32          0.010           1.0         10
# 20           20       9          32          0.001           1.0         10
# 53           53       9          32          0.010           1.0         50
# 100         100       6         256          0.010           1.0         10
# 101         101       9         256          0.010           1.0         10
# ..          ...     ...         ...            ...           ...        ...
# 31           31       6          32          0.010           0.2         30
# 44           44       9          32          0.010           0.5         50
# 34           34       6          32          0.010           0.2         50
# 32           32       9          32          0.010           0.2         30
# 35           35       9          32          0.010           0.2         50
#
#       Accuracy                                       train_losses  \
# 46    4.050000  [2.3537378311157227, 2.292309284210205, 2.2915...
# 20    7.720000  [2.3537378311157227, 2.2922515869140625, 2.289...
# 53    8.050000  [2.3198084831237793, 2.275465965270996, 2.3148...
# 100   8.100000  [2.31144642829895, 2.3155324459075928, 2.31856...
# 101   8.350000  [2.31144642829895, 2.3155324459075928, 2.31856...
# ..         ...                                                ...
# 31   86.019997  [2.3386623859405518, 2.3225855827331543, 2.328...
# 44   86.510002  [2.3311424255371094, 2.287510395050049, 2.2955...
# 34   86.650002  [2.3274571895599365, 2.2662808895111084, 2.290...
# 32   86.769997  [2.3386623859405518, 2.3225855827331543, 2.328...
# 35   87.860001  [2.3274571895599365, 2.2662808895111084, 2.290...
#
#                                          train_counter  \
# 46   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 20   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 53   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 100  [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 101  [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# ..                                                 ...
# 31   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 44   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 34   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 32   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
# 35   [0, 640, 1280, 1920, 2560, 3200, 3840, 4480, 5...
#
#                                            test_losses  \
# 46   [2.3217968017578126, 2.3074344482421876, 2.307...
# 20   [2.3217968017578126, 2.3142005126953125, 2.310...
# 53   [2.3021302978515625, 2.3000744384765626, 2.299...
# 100  [2.3217968017578126, 2.3130224609375, 2.309640...
# 101  [2.3217968017578126, 2.3130224609375, 2.309640...
# ..                                                 ...
# 31   [2.312999560546875, 0.6073333923339844, 0.5137...
# 44   [2.3021302978515625, 0.6238296569824219, 0.537...
# 34   [2.3021302978515625, 0.5811319152832031, 0.487...
# 32   [2.312999560546875, 0.6073333923339844, 0.5137...
# 35   [2.3021302978515625, 0.5811319152832031, 0.487...
#
#                                           test_counter
# 46   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 20   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 53   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 100  [0, 60000, 120000, 180000, 240000, 300000, 360...
# 101  [0, 60000, 120000, 180000, 240000, 300000, 360...
# ..                                                 ...
# 31   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 44   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 34   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 32   [0, 60000, 120000, 180000, 240000, 300000, 360...
# 35   [0, 60000, 120000, 180000, 240000, 300000, 360...
#
# [108 rows x 11 columns]

# %%
def graph(df):
    
    l = ["Epochs", "Batch Size", "Learning Rate", "Dropout Rate", "FC1 Nodes"]
    for i in l:
        grouped_df = df.groupby(i).agg({'Accuracy': ['mean', 'median']})
        grouped_df.columns = [' '.join(col).strip() for col in grouped_df.columns.values]

        grouped_df.plot(kind='bar')
        plt.xlabel(i)
        plt.ylabel('Accuracy')
        x = 'Mean and Median Accuracy by ' + i
        plt.title(x)
        plt.show()

# %%
graph(df)
